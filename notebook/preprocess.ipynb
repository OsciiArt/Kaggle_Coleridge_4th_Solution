# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, glob, pickle, time, gc, copy, sys, json, re
import warnings

from tqdm import tqdm
tqdm.pandas()

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100) # 表示できる列数
sys.path.append('../src')
from utils import ri, pickle_load, pickle_save

# %%
# config
params = {}
### params directory
params['INPUT_DIR'] = "../input/orig"
params['OUTPUT_DIR'] = "../output"

# %%
# load train data
df_train = pd.read_csv(params['INPUT_DIR']+"/train.csv")
print(df_train.shape)
df_train.head()
# Out:
# (19661, 5)
#                                      Id  \
# 0  d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1  2f26f645-3dec-485d-b68d-f013c9e05e60
# 2  c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3  5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4  c754dec7-c5a3-4337-9892-c02158475064
#
#                                            pub_title  \
# 0  The Impact of Dual Enrollment on College Degre...
# 1  Educational Attainment of High School Dropouts...
# 2  Differences in Outcomes for Female and Male St...
# 3  Stepping Stone and Option Value in a Model of ...
# 4  Parental Effort, School Resources, and Student...
#
#                            dataset_title  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            dataset_label  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# ...

# %%
df_train_reduced = df_train[df_train['Id'].duplicated()==False].reset_index(drop=True)
print(df_train_reduced.shape)
df_train_reduced.head()
# Out:
# (14316, 5)
#                                      Id  \
# 0  d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1  2f26f645-3dec-485d-b68d-f013c9e05e60
# 2  c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3  5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4  c754dec7-c5a3-4337-9892-c02158475064
#
#                                            pub_title  \
# 0  The Impact of Dual Enrollment on College Degre...
# 1  Educational Attainment of High School Dropouts...
# 2  Differences in Outcomes for Female and Male St...
# 3  Stepping Stone and Option Value in a Model of ...
# 4  Parental Effort, School Resources, and Student...
#
#                            dataset_title  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            dataset_label  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# ...

# %%
def read_append_return(filename, train_files_path, output='text'):
    """
    Function to read json file and then return the text data from them and append to the dataframe
    """
    json_path = os.path.join(train_files_path, (filename+'.json'))
    headings = []
    contents = []
    combined = []
    with open(json_path, 'r') as f:
        json_decode = json.load(f)
        for data in json_decode:
            headings.append(data.get('section_title'))
            contents.append(data.get('text'))
            combined.append(data.get('section_title'))
            combined.append(data.get('text'))
    
    all_headings = ' '.join(headings)
    all_contents = ' '.join(contents)
    all_data = '. '.join(combined)
    
    if output == 'text':
        return all_contents
    elif output == 'head':
        return all_headings
    else:
        return all_data
    
train_files_path = params['INPUT_DIR']+"/train"
df_train_reduced['text'] = df_train_reduced['Id'].progress_apply(lambda x: read_append_return(x, train_files_path))
# Out:
# 100%|██████████| 14316/14316 [01:39<00:00, 143.19it/s]

# %%
def clean_text(txt):
    return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower()).strip()

df_train_reduced['clean_text'] = df_train_reduced['text'].progress_apply(clean_text)
df_train_reduced.head()
# Out:
# 100%|██████████| 14316/14316 [00:42<00:00, 337.01it/s]
#                                      Id  \
# 0  d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1  2f26f645-3dec-485d-b68d-f013c9e05e60
# 2  c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3  5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4  c754dec7-c5a3-4337-9892-c02158475064
#
#                                            pub_title  \
# 0  The Impact of Dual Enrollment on College Degre...
# 1  Educational Attainment of High School Dropouts...
# 2  Differences in Outcomes for Female and Male St...
# 3  Stepping Stone and Option Value in a Model of ...
# 4  Parental Effort, School Resources, and Student...
#
#                            dataset_title  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            dataset_label  \
# ...

# %%
pickle_save(params['OUTPUT_DIR']+'/df_train_reduced.pkl', df_train_reduced)
