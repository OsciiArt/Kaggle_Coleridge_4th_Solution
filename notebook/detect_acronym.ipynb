# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os, glob, pickle, time, gc, copy, sys
import warnings
from tqdm import tqdm
import re
from concurrent.futures import ThreadPoolExecutor

tqdm.pandas()
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100) # 表示できる列数

sys.path.append('../src')
from utils import ri, pickle_load, pickle_save
import nltk

# %%
# config
params = {}
### params directory
params['INPUT_DIR'] = "../input/orig"
params['OUTPUT_DIR'] = "../output"

# %%
df_train = pd.read_csv(params['INPUT_DIR']+"/train.csv")
df_train.head()
# Out:
#                                      Id  \
# 0  d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1  2f26f645-3dec-485d-b68d-f013c9e05e60
# 2  c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3  5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4  c754dec7-c5a3-4337-9892-c02158475064
#
#                                            pub_title  \
# 0  The Impact of Dual Enrollment on College Degre...
# 1  Educational Attainment of High School Dropouts...
# 2  Differences in Outcomes for Female and Male St...
# 3  Stepping Stone and Option Value in a Model of ...
# 4  Parental Effort, School Resources, and Student...
#
#                            dataset_title  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            dataset_label  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            cleaned_label
# 0  national education longitudinal study
# 1  national education longitudinal study
# 2  national education longitudinal study
# 3  national education longitudinal study
# 4  national education longitudinal study

# %%
df_train_reduced = pickle_load(params['OUTPUT_DIR']+"/df_train_reduced.pkl")
df_train_reduced.head()
# Out:
#                                      Id  \
# 0  d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1  2f26f645-3dec-485d-b68d-f013c9e05e60
# 2  c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3  5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4  c754dec7-c5a3-4337-9892-c02158475064
#
#                                            pub_title  \
# 0  The Impact of Dual Enrollment on College Degre...
# 1  Educational Attainment of High School Dropouts...
# 2  Differences in Outcomes for Female and Male St...
# 3  Stepping Stone and Option Value in a Model of ...
# 4  Parental Effort, School Resources, and Student...
#
#                            dataset_title  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            dataset_label  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            cleaned_label  \
# 0  national education longitudinal study
# 1  national education longitudinal study
# 2  national education longitudinal study
# 3  national education longitudinal study
# 4  national education longitudinal study
#
#                                                 text  \
# 0  This study used data from the National Educati...
# 1  Dropping out of high school is not necessarily...
# 2   , stress satisfactory outcomes for all youth,...
# 3  Federal Reserve Bank of Richmond S1. Accountin...
# 4  This article investigates an important factor ...
#
#                                           clean_text
# 0  this study used data from the national educati...
# 1  dropping out of high school is not necessarily...
# 2  stress satisfactory outcomes for all youth inc...
# 3  federal reserve bank of richmond s1 accounting...
# 4  this article investigates an important factor ...

# %% [markdown]
# # Train label

# %%
def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    if len(a)==0 or len(b)==0:
        return 0
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

def clean_text(txt):
    return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower()).strip()

# %%
df_label = df_train['cleaned_label'].value_counts().reset_index()
df_label.columns = ['cleaned_label', 'count']
df_label['-count'] = -df_label['count']
df_label = df_label.sort_values(['-count', 'cleaned_label']).reset_index(drop=True)
df_label['target'] = np.arange(len(df_label))
df_label['cleaned_label'] = df_label['cleaned_label'].apply(clean_text)

df_tmp1 = df_train[['dataset_label', 'cleaned_label', 'dataset_title']]
df_tmp2 = df_train[['dataset_title', 'cleaned_label', 'dataset_title']]
df_tmp3 = df_train[['cleaned_label', 'cleaned_label', 'dataset_title']]
df_tmp1.columns = ['label', 'cleaned_label', 'dataset_title']
df_tmp2.columns = ['label', 'cleaned_label', 'dataset_title']
df_tmp3.columns = ['label', 'cleaned_label', 'dataset_title']
df_label2 = pd.concat([df_tmp1, df_tmp2, df_tmp3])

df_label2['label'] = df_label2['label'].apply(lambda x: x.lower())
df_label2['cleaned_label_my'] = df_label2['label'].apply(clean_text)
df_label2['cleaned_label'] = df_label2['cleaned_label'].apply(clean_text)
df_label2 = df_label2[df_label2['label'].duplicated()==False].reset_index(drop=True)
df_label2 = pd.merge(df_label2, df_label, on='cleaned_label', how='left')
print(df_label2.shape)
print(np.sum(pd.isna(df_label2['target'])))
# print(df_label2[df_label2['target']==1])
df_label2 = df_label2.sort_values(['-count', 'label']).reset_index(drop=True)
df_label2['target_relabeled'] = df_label2['target']
df_label2['target_relabeled'][df_label2['cleaned_label']!=df_label2['cleaned_label_my']] =\
    np.arange(np.sum(df_label2['cleaned_label']!=df_label2['cleaned_label_my'])) + df_label2['target'].max()+1
print("not match: ", np.sum(df_label2['cleaned_label']!=df_label2['cleaned_label_my']))
print("unique cleaned_label_my: ", len(df_label2['cleaned_label_my'].unique()))
print(df_label2['target'].max())
print(df_label2['target_relabeled'].max())

df_label_train = df_label2.copy()
print(df_label_train.shape)
df_label_train.head()
# Out:
# (180, 7)
# 0
# not match:  3
# unique cleaned_label_my:  133
# 129
# 132
# (180, 8)
#                                                label  \
# 0                                               adni
# 1  alzheimer s disease neuroimaging initiative adni
# 2  alzheimer's disease neuroimaging initiative (a...
# 3  trends in international mathematics and scienc...
# 4              baltimore longitudinal study of aging
#
#                                        cleaned_label  \
# 0                                               adni
# 1   alzheimer s disease neuroimaging initiative adni
# 2   alzheimer s disease neuroimaging initiative adni
# 3  trends in international mathematics and scienc...
# 4              baltimore longitudinal study of aging
#
#                                        dataset_title  \
# 0  Alzheimer's Disease Neuroimaging Initiative (A...
# 1  Alzheimer's Disease Neuroimaging Initiative (A...
# 2  Alzheimer's Disease Neuroimaging Initiative (A...
# 3  Trends in International Mathematics and Scienc...
# 4       Baltimore Longitudinal Study of Aging (BLSA)
#
#                                     cleaned_label_my  count  -count  target  \
# 0                                               adni   3673   -3673       0
# 1   alzheimer s disease neuroimaging initiative adni   2400   -2400       1
# 2   alzheimer s disease neuroimaging initiative adni   2400   -2400       1
# 3  trends in international mathematics and scienc...   1163   -1163       2
# 4              baltimore longitudinal study of aging   1156   -1156       3
#
#    target_relabeled
# 0                 0
# 1                 1
# 2                 1
# 3                 2
# 4                 3

# %% [markdown]
# # train acronym

# %%
acronym_list = [
    ['National Education Longitudinal Study', 'nels'],
#     ['NOAA Tide Gauge', 'nan'],
    ['Sea, Lake, and Overland Surges from Hurricanes', 'slosh'],
    ['Coastal Change Analysis Program', 'c-cap'],
    ['Aging Integrated Database (AGID)', 'agid'],
    ["Alzheimer's Disease Neuroimaging Initiative (ADNI)", 'adni'],
    ['Baltimore Longitudinal Study of Aging (BLSA)', 'blsa'],
    ['Agricultural Resource Management Survey', 'arms'],
    ['Beginning Postsecondary Student', 'bps'],
    ["The National Institute on Aging Genetics of Alzheimer's Disease Data Storage Site (NIAGADS)", 'niagads'],
    ['Common Core of Data', 'ccd'],
#     ['Survey of Industrial Research and Development', 'nan'],
    ['Baccalaureate and Beyond', 'b&b'],
    ['International Best Track Archive for Climate Stewardship', 'IBTrACS'],
    ['National Teacher and Principal Survey', 'ntps'],
    ['Higher Education Research and Development Survey', 'herd'],
    ['Survey of Earned Doctorates', 'sed'],
    ['School Survey on Crime and Safety', 'ssocs'],
    ['World Ocean Database', 'wod'],
    ['Program for the International Assessment of Adult Competencies', 'piaac'],
    ['Early Childhood Longitudinal Study', 'ecls'],
#     ['Survey of Graduate Students and Postdoctorates in Science and Engineering', 'nan'],
    ['Trends in International Mathematics and Science Study', 'timss'],
    ['Education Longitudinal Study', 'els'],
    ['Optimum Interpolation Sea Surface Temperature', 'oisst'],
    ['National Assessment of Education Progress', 'naep'],
    ['High School Longitudinal Study', 'hsls'],
    ['Survey of Doctorate Recipients', 'sdr'],
    ['Rural-Urban Continuum Codes', 'rucc'],
#     ['Survey of Science and Engineering Research Facilities', 'nan'],
#     ['FFRDC Research and Development Survey', 'nan'],
#     ['Survey of State Government Research and Development', 'nan'],
    ['Advanced National Seismic System (ANSS) Comprehensive Catalog (ComCat)', 'comcat'],
#     ['Census of Agriculture', 'nan'],
    ['North American Breeding Bird Survey (BBS)', 'bbs'],
    ['COVID-19 Open Research Dataset (CORD-19)', 'cord-19'],
    ['Complexity Science Hub COVID-19 Control Strategies List (CCCSL)', 'cccsl'],
#     ['Our World in Data COVID-19 dataset', 'nan'],
    ['COVID-19 Precision Medicine Analytics Platform Registry (JH-CROWN)', 'jh-crown'],
    ['Characterizing Health Associated Risks, and Your Baseline Disease In SARS-COV-2 (CHARYBDIS)', 'charybdis'],
#     ['COVID-19 Deaths data', 'nan'],
#     ['SARS-CoV-2 genome sequence', 'nan'],
#     ['COVID-19 Image Data Collection', 'nan'],
    ['RSNA International COVID-19 Open Radiology Database (RICORD)', 'ricord'],
#     ['CAS COVID-19 antiviral candidate compounds dataset', 'nan'],
]
df_label_train_acronym = pd.DataFrame(acronym_list, columns=['dataset_title', 'acronym'])
df_label_train_acronym['acronym_clean'] = df_label_train_acronym['acronym'].apply(clean_text)
df_label_train_acronym
# Out:
#                                         dataset_title    acronym acronym_clean
# 0               National Education Longitudinal Study       nels          nels
# 1      Sea, Lake, and Overland Surges from Hurricanes      slosh         slosh
# 2                     Coastal Change Analysis Program      c-cap         c cap
# 3                    Aging Integrated Database (AGID)       agid          agid
# 4   Alzheimer's Disease Neuroimaging Initiative (A...       adni          adni
# 5        Baltimore Longitudinal Study of Aging (BLSA)       blsa          blsa
# 6             Agricultural Resource Management Survey       arms          arms
# 7                     Beginning Postsecondary Student        bps           bps
# 8   The National Institute on Aging Genetics of Al...    niagads       niagads
# 9                                 Common Core of Data        ccd           ccd
# 10                           Baccalaureate and Beyond        b&b           b b
# 11  International Best Track Archive for Climate S...    IBTrACS       ibtracs
# 12              National Teacher and Principal Survey       ntps          ntps
# 13   Higher Education Research and Development Survey       herd          herd
# 14                        Survey of Earned Doctorates        sed           sed
# 15                  School Survey on Crime and Safety      ssocs         ssocs
# 16                               World Ocean Database        wod           wod
# 17  Program for the International Assessment of Ad...      piaac         piaac
# 18                 Early Childhood Longitudinal Study       ecls          ecls
# 19  Trends in International Mathematics and Scienc...      timss         timss
# 20                       Education Longitudinal Study        els           els
# 21      Optimum Interpolation Sea Surface Temperature      oisst         oisst
# 22          National Assessment of Education Progress       naep          naep
# 23                     High School Longitudinal Study       hsls          hsls
# 24                     Survey of Doctorate Recipients        sdr           sdr
# 25                        Rural-Urban Continuum Codes       rucc          rucc
# 26  Advanced National Seismic System (ANSS) Compre...     comcat        comcat
# 27          North American Breeding Bird Survey (BBS)        bbs           bbs
# 28           COVID-19 Open Research Dataset (CORD-19)    cord-19       cord 19
# 29  Complexity Science Hub COVID-19 Control Strate...      cccsl         cccsl
# 30  COVID-19 Precision Medicine Analytics Platform...   jh-crown      jh crown
# 31  Characterizing Health Associated Risks, and Yo...  charybdis     charybdis
# 32  RSNA International COVID-19 Open Radiology Dat...     ricord        ricord

# %% [markdown]
# # Detect acronym ver1

# %%
def detect_keywords(text, keywords):
    for keyword in keywords:
        if keyword in text:
            return True
    return False

def det_acronym_ver1(text, keywords, TH_LEN_CHAR = 3):
    ans = []
    # text = re.sub("-", " ", text)
    words = text.split()
    for i, word in enumerate(words):
        if word[0]!='(' or word[-1]!=')': continue # (XXX)の形でなければスルー
        acronym_cand = word[1:-1]
        if acronym_cand.lower()==acronym_cand: continue # 大文字が一つもないならスルー
        len_acronym_cand = len(acronym_cand)
        if len_acronym_cand<TH_LEN_CHAR: continue # 3文字以下ならスルー
        acronym_cand_lower = acronym_cand.lower()
        acronym_cand_reverse = acronym_cand_lower[::-1]
        words_cand = words[np.clip(i-len_acronym_cand*3, 0, i):i] # (XXX)の前の数単語を抽出
#         print("len_acronym_cand", len_acronym_cand)
#         print("i", i)
#         print(words_cand, 1)
        words_cand = ' '.join(words_cand).strip()
# #         print(words_cand, 1)
        words_cand = re.sub('[^A-Za-z0-9]+', ' ', words_cand).strip()
#         print(words_cand, 1)
        words_cand = words_cand.split(" ")
        words_cand_reverse = words_cand[::-1]
        idx = 0 # acronym_candの文字index
#         print("words_cand_reverse[0]", words_cand_reverse[0])
        for j, word in enumerate(words_cand_reverse):
            if idx==len_acronym_cand:
                break
            if len(word)==0:
                continue
            if word[0].lower()==acronym_cand_reverse[idx]:
                if idx==len_acronym_cand-1: # 1文字目を検出
                    idx_start = j # dataset名の1単語目のindex
                idx += 1
        if idx==len_acronym_cand:
            words_reverse = words_cand_reverse[:idx_start+1]
            dataset = ' '.join(words_reverse[::-1]).strip().lower()
            if detect_keywords(dataset, keywords):
                acronym = acronym_cand
#                 print("Acronym: {}".format(acronym))
#                 print("Dataset: {}".format(dataset))
                ans.append([acronym_cand, dataset])
        return ans
    
keywords = [
    'study',
    'studies',
    'data',
    'survey',
    'panel',
    'census',
    'cohort',
    'longitudinal',
    'registry',
]    
df_train_reduced['det_acronym'] = df_train_reduced['text'].progress_apply(lambda x: det_acronym_ver1(x, keywords))
df_train_reduced.head()
# Out:
# 100%|██████████| 14316/14316 [00:10<00:00, 1423.15it/s]
#                                      Id  \
# 0  d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1  2f26f645-3dec-485d-b68d-f013c9e05e60
# 2  c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3  5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4  c754dec7-c5a3-4337-9892-c02158475064
#
#                                            pub_title  \
# 0  The Impact of Dual Enrollment on College Degre...
# 1  Educational Attainment of High School Dropouts...
# 2  Differences in Outcomes for Female and Male St...
# 3  Stepping Stone and Option Value in a Model of ...
# 4  Parental Effort, School Resources, and Student...
#
#                            dataset_title  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            dataset_label  \
# 0  National Education Longitudinal Study
# 1  National Education Longitudinal Study
# 2  National Education Longitudinal Study
# 3  National Education Longitudinal Study
# 4  National Education Longitudinal Study
#
#                            cleaned_label  \
# 0  national education longitudinal study
# 1  national education longitudinal study
# 2  national education longitudinal study
# 3  national education longitudinal study
# 4  national education longitudinal study
#
#                                                 text  \
# 0  This study used data from the National Educati...
# 1  Dropping out of high school is not necessarily...
# 2   , stress satisfactory outcomes for all youth,...
# 3  Federal Reserve Bank of Richmond S1. Accountin...
# 4  This article investigates an important factor ...
#
#                                           clean_text  \
# 0  this study used data from the national educati...
# 1  dropping out of high school is not necessarily...
# 2  stress satisfactory outcomes for all youth inc...
# 3  federal reserve bank of richmond s1 accounting...
# 4  this article investigates an important factor ...
#
#                                        det_acronym
# 0                                               []
# 1                                               []
# 2                                               []
# 3                                               []
# 4  [[NELS, national education longitudinal study]]

# %%
tmp = []
# ri(df_traintest)なしだとここでエラー
for i in range(len(df_train_reduced)):
    if df_train_reduced['det_acronym'][i] is not None:
        tmp += df_train_reduced['det_acronym'][i]
df_train_acronym = pd.DataFrame(tmp)
df_train_acronym.columns = ['acronym', 'base']
df_train_acronym['base_acronym'] = df_train_acronym['base']+"|"+df_train_acronym['acronym']
df_train_acronym_tmp = df_train_acronym[df_train_acronym['base_acronym'].duplicated()==False]


df_agg = df_train_acronym.groupby('base_acronym')['base'].agg(len).reset_index()
cols_tmp = df_agg.columns.tolist()
cols_tmp[-1] = 'count_BA'
df_agg.columns = cols_tmp
df_train_acronym = df_train_acronym[df_train_acronym['base_acronym'].duplicated()==False]
df_train_acronym = pd.merge(df_train_acronym_tmp, df_agg, on='base_acronym', how='left')

df_train_acronym['train'] = True
print(df_train_acronym.shape)
# acronym unique =256
# BA unique 325
df_train_acronym.head(30)
# Out:
# (325, 5)
#    acronym                                               base  \
# 0     NELS              national education longitudinal study
# 1      NLS                        national longitudinal study
# 2      BPS  beginning postsecondary student longitudinal s...
# 3     NELS   national educational longitudinal survey of 1988
# 4      HSB        high school and beyond longitudinal dataset
# 5     NELS      national education longitudinal study of 1988
# 6     NHES                national household education survey
# 7     NLSY              national longitudinal survey of youth
# 8     ATUS                           american time use survey
# 9    TIMSS  trends in international mathematics and scienc...
# 10     CPS                          current population survey
# 11     WLS                       wisconsin longitudinal study
# 12   PIRLS   progress in international reading literacy study
# 13    NELS  national education longitudinal study 1988 stu...
# 14     BPS  beginning postsecondary students longitudinal ...
# 15    ECLS  early childhood longitudinal study kindergarte...
# 16   IPEDS     integrated postsecondary education data system
# 17     NLS                       national longitudinal survey
# 18    NSFH         national survey of families and households
# 19   IPUMS             integrated public use microdata series
# 20    SMSG                     school mathematics study group
# 21    NELS             national education longitudinal survey
# 22    HSES                    high school effectiveness study
# 23     FHS                             framingham heart study
# 24     CPS                         current population surveys
# 25     GSS                              general social survey
# 26     SRI                          survey research institute
# 27     GSS                             general social surveys
# 28     HSB                      high school and beyond survey
# 29    USGS                              u s geological survey
#
#                                          base_acronym  count_BA  train
# 0          national education longitudinal study|NELS        24   True
# 1                     national longitudinal study|NLS         1   True
# 2   beginning postsecondary student longitudinal s...         2   True
# 3   national educational longitudinal survey of 19...         2   True
# 4     high school and beyond longitudinal dataset|HSB         1   True
# 5   national education longitudinal study of 1988|...         4   True
# 6            national household education survey|NHES         4   True
# 7          national longitudinal survey of youth|NLSY         4   True
# 8                       american time use survey|ATUS         1   True
# 9   trends in international mathematics and scienc...       194   True
# 10                      current population survey|CPS        13   True
# 11                   wisconsin longitudinal study|WLS         1   True
# 12  progress in international reading literacy stu...        15   True
# 13  national education longitudinal study 1988 stu...         1   True
# 14  beginning postsecondary students longitudinal ...         1   True
# 15  early childhood longitudinal study kindergarte...         1   True
# 16  integrated postsecondary education data system...        18   True
# 17                   national longitudinal survey|NLS         1   True
# 18    national survey of families and households|NSFH         1   True
# 19       integrated public use microdata series|IPUMS         1   True
# 20                school mathematics study group|SMSG         1   True
# 21        national education longitudinal survey|NELS         3   True
# 22               high school effectiveness study|HSES         1   True
# 23                         framingham heart study|FHS         3   True
# 24                     current population surveys|CPS         2   True
# 25                          general social survey|GSS         2   True
# 26                      survey research institute|SRI         1   True
# 27                         general social surveys|GSS         1   True
# 28                  high school and beyond survey|HSB         1   True
# 29                         u s geological survey|USGS        36   True

# %%
df_label_acronym_ver1_all = df_train_acronym.copy()
print(df_label_acronym_ver1_all.shape)
df_label_acronym_ver1_all.head()
# Out:
# (325, 5)
#   acronym                                               base  \
# 0    NELS              national education longitudinal study
# 1     NLS                        national longitudinal study
# 2     BPS  beginning postsecondary student longitudinal s...
# 3    NELS   national educational longitudinal survey of 1988
# 4     HSB        high school and beyond longitudinal dataset
#
#                                         base_acronym  count_BA  train
# 0         national education longitudinal study|NELS        24   True
# 1                    national longitudinal study|NLS         1   True
# 2  beginning postsecondary student longitudinal s...         2   True
# 3  national educational longitudinal survey of 19...         2   True
# 4    high school and beyond longitudinal dataset|HSB         1   True

# %%
def get_match(x, ref_labels, threshold=0.5):
    for label in ref_labels:
        if jaccard(x, label)>=threshold:
            return label
    return 'no_match'

df_label_acronym_ver1_all['match'] = df_label_acronym_ver1_all['base'].apply(get_match, ref_labels=df_label2['cleaned_label_my'])
print((df_label_acronym_ver1_all['match']=='no_match').sum())
print(df_label_acronym_ver1_all.shape)
df_label_acronym_ver1_all.head()
# Out:
# 270
# (325, 6)
#   acronym                                               base  \
# 0    NELS              national education longitudinal study
# 1     NLS                        national longitudinal study
# 2     BPS  beginning postsecondary student longitudinal s...
# 3    NELS   national educational longitudinal survey of 1988
# 4     HSB        high school and beyond longitudinal dataset
#
#                                         base_acronym  count_BA  train  \
# 0         national education longitudinal study|NELS        24   True
# 1                    national longitudinal study|NLS         1   True
# 2  beginning postsecondary student longitudinal s...         2   True
# 3  national educational longitudinal survey of 19...         2   True
# 4    high school and beyond longitudinal dataset|HSB         1   True
#
#                                                match
# 0                       education longitudinal study
# 1                       education longitudinal study
# 2  beginning postsecondary students longitudinal ...
# 3                                           no_match
# 4                                           no_match

# %%
df_label_acronym_ver1_all[(df_label_acronym_ver1_all['match']!='no_match')&(df_label_acronym_ver1_all['match'].duplicated())].head(30)
# Out:
#     acronym                                               base  \
# 1       NLS                        national longitudinal study
# 5      NELS      national education longitudinal study of 1988
# 11      WLS                       wisconsin longitudinal study
# 13     NELS  national education longitudinal study 1988 stu...
# 59     ARMS                     and resource management survey
# 65      BPS  beginning postsecondary students longitudinal ...
# 66    NLTS2           national longitudinal transition study 2
# 67    TIMSS  third international mathematics and science study
# 81     TLSA                 taiwan longitudinal study of aging
# 105   TIMSS            trends in mathematics and science study
# 116    NELS            national educational longitudinal study
# 151   TIMSS    the international mathematics and science study
# 154   TIMSS                   trends in math and science study
# 163   TIMSS  trends in international mathematics and scienc...
# 169    GELS           gerontology education longitudinal study
# 170     ELS               education longitudinal study of 2002
# 172    CELS           citizenship education longitudinal study
# 208     CCD                                   common core data
# 212    KELS                korean education longitudinal study
# 213     ELS                       education longitudinal study
# 222     BPS  beginning postsecondary students longitudinal ...
# 228    NTPS              national teacher and principal survey
# 231    NELS               national education lonotudinal study
# 233    NELS            national education longitudinal studies
# 236   ECLSK  early childhood longitudinal study kindergarte...
# 238    ECLS               early childhood longitudinal studies
# 240    HSLS             high school longitudinal study of 2009
# 253     SDR                      survey of doctoral recipients
# 267    ARMS           agricultural resources management survey
# 283    ARMS             agriculture resource management survey
#
#                                           base_acronym  count_BA  train  \
# 1                      national longitudinal study|NLS         1   True
# 5    national education longitudinal study of 1988|...         4   True
# 11                    wisconsin longitudinal study|WLS         1   True
# 13   national education longitudinal study 1988 stu...         1   True
# 59                 and resource management survey|ARMS         4   True
# 65   beginning postsecondary students longitudinal ...         6   True
# 66      national longitudinal transition study 2|NLTS2         2   True
# 67   third international mathematics and science st...         6   True
# 81             taiwan longitudinal study of aging|TLSA         1   True
# 105      trends in mathematics and science study|TIMSS         2   True
# 116       national educational longitudinal study|NELS         6   True
# 151  the international mathematics and science stud...         1   True
# 154             trends in math and science study|TIMSS         1   True
# 163  trends in international mathematics and scienc...         1   True
# 169      gerontology education longitudinal study|GELS         1   True
# 170           education longitudinal study of 2002|ELS         1   True
# 172      citizenship education longitudinal study|CELS         3   True
# 208                               common core data|CCD         1   True
# 212           korean education longitudinal study|KELS         1   True
# 213                   education longitudinal study|ELS         4   True
# 222  beginning postsecondary students longitudinal ...         1   True
# 228         national teacher and principal survey|NTPS         5   True
# 231          national education lonotudinal study|NELS         1   True
# 233       national education longitudinal studies|NELS         1   True
# 236  early childhood longitudinal study kindergarte...         1   True
# 238          early childhood longitudinal studies|ECLS         1   True
# 240        high school longitudinal study of 2009|HSLS         1   True
# 253                  survey of doctoral recipients|SDR         3   True
# 267      agricultural resources management survey|ARMS         2   True
# 283        agriculture resource management survey|ARMS         2   True
#
#                                                  match
# 1                         education longitudinal study
# 5                         education longitudinal study
# 11                        education longitudinal study
# 13                        education longitudinal study
# 59             agricultural resource management survey
# 65                    beginning postsecondary students
# 66               national education longitudinal study
# 67   trends in international mathematics and scienc...
# 81               baltimore longitudinal study of aging
# 105  trends in international mathematics and scienc...
# 116              national education longitudinal study
# 151  trends in international mathematics and scienc...
# 154  trends in international mathematics and scienc...
# 163  trends in international mathematics and scienc...
# 169                       education longitudinal study
# 170                       education longitudinal study
# 172                       education longitudinal study
# 208                                common core of data
# 212                       education longitudinal study
# 213                       education longitudinal study
# 222                   beginning postsecondary students
# 228              national teacher and principal survey
# 231              national education longitudinal study
# 233              national education longitudinal study
# 236                 early childhood longitudinal study
# 238                 early childhood longitudinal study
# 240                     high school longitudinal study
# 253                     survey of doctorate recipients
# 267            agricultural resource management survey
# 283            agricultural resource management survey

# %%
def delete_keywords(x, keywords):
    x_split = x.split()
    x_new = []
    for word in x_split:
        if word not in keywords:
            x_new.append(word)
    x_new = ' '.join(x_new)
    return x_new

keywords2 = keywords + ['of', 'the', 'national', 'education']
df_label2['label-keywords'] = df_label2['cleaned_label_my'].apply(lambda x: delete_keywords(x, keywords2))
df_label2.head()
# Out:
#                                                label  \
# 0                                               adni
# 1  alzheimer s disease neuroimaging initiative adni
# 2  alzheimer's disease neuroimaging initiative (a...
# 3  trends in international mathematics and scienc...
# 4              baltimore longitudinal study of aging
#
#                                        cleaned_label  \
# 0                                               adni
# 1   alzheimer s disease neuroimaging initiative adni
# 2   alzheimer s disease neuroimaging initiative adni
# 3  trends in international mathematics and scienc...
# 4              baltimore longitudinal study of aging
#
#                                        dataset_title  \
# 0  Alzheimer's Disease Neuroimaging Initiative (A...
# 1  Alzheimer's Disease Neuroimaging Initiative (A...
# 2  Alzheimer's Disease Neuroimaging Initiative (A...
# 3  Trends in International Mathematics and Scienc...
# 4       Baltimore Longitudinal Study of Aging (BLSA)
#
#                                     cleaned_label_my  count  -count  target  \
# 0                                               adni   3673   -3673       0
# 1   alzheimer s disease neuroimaging initiative adni   2400   -2400       1
# 2   alzheimer s disease neuroimaging initiative adni   2400   -2400       1
# 3  trends in international mathematics and scienc...   1163   -1163       2
# 4              baltimore longitudinal study of aging   1156   -1156       3
#
#    target_relabeled                                    label-keywords
# 0                 0                                              adni
# 1                 1  alzheimer s disease neuroimaging initiative adni
# 2                 1  alzheimer s disease neuroimaging initiative adni
# 3                 2   trends in international mathematics and science
# 4                 3                                   baltimore aging

# %%
df_label_acronym_ver1_all['label-keywords'] = df_label_acronym_ver1_all['base'].apply(lambda x: delete_keywords(x, keywords))
df_label_acronym_ver1_all['len_label-keywords'] = df_label_acronym_ver1_all['label-keywords'].apply(lambda x: len(x.split()))
df_label_acronym_ver1_all.head()
# Out:
#   acronym                                               base  \
# 0    NELS              national education longitudinal study
# 1     NLS                        national longitudinal study
# 2     BPS  beginning postsecondary student longitudinal s...
# 3    NELS   national educational longitudinal survey of 1988
# 4     HSB        high school and beyond longitudinal dataset
#
#                                         base_acronym  count_BA  train  \
# 0         national education longitudinal study|NELS        24   True
# 1                    national longitudinal study|NLS         1   True
# 2  beginning postsecondary student longitudinal s...         2   True
# 3  national educational longitudinal survey of 19...         2   True
# 4    high school and beyond longitudinal dataset|HSB         1   True
#
#                                                match  \
# 0                       education longitudinal study
# 1                       education longitudinal study
# 2  beginning postsecondary students longitudinal ...
# 3                                           no_match
# 4                                           no_match
#
#                     label-keywords  len_label-keywords
# 0               national education                   2
# 1                         national                   1
# 2  beginning postsecondary student                   3
# 3     national educational of 1988                   4
# 4   high school and beyond dataset                   5

# %%
df_label_acronym_ver1_all['match_train-keywords'] = df_label_acronym_ver1_all['label-keywords'].apply(lambda x:
    get_match(x, ref_labels=df_label2['label-keywords'], threshold=0.75))
df_label_acronym_ver1_all.head()
# Out:
#   acronym                                               base  \
# 0    NELS              national education longitudinal study
# 1     NLS                        national longitudinal study
# 2     BPS  beginning postsecondary student longitudinal s...
# 3    NELS   national educational longitudinal survey of 1988
# 4     HSB        high school and beyond longitudinal dataset
#
#                                         base_acronym  count_BA  train  \
# 0         national education longitudinal study|NELS        24   True
# 1                    national longitudinal study|NLS         1   True
# 2  beginning postsecondary student longitudinal s...         2   True
# 3  national educational longitudinal survey of 19...         2   True
# 4    high school and beyond longitudinal dataset|HSB         1   True
#
#                                                match  \
# 0                       education longitudinal study
# 1                       education longitudinal study
# 2  beginning postsecondary students longitudinal ...
# 3                                           no_match
# 4                                           no_match
#
#                     label-keywords  len_label-keywords  \
# 0               national education                   2
# 1                         national                   1
# 2  beginning postsecondary student                   3
# 3     national educational of 1988                   4
# 4   high school and beyond dataset                   5
#
#               match_train-keywords
# 0                         no_match
# 1                         no_match
# 2  beginning postsecondary student
# 3                         no_match
# 4                         no_match

# %%
df_label_acronym_ver1_all[
    (df_label_acronym_ver1_all['match_train-keywords']!='no_match')
    &(df_label_acronym_ver1_all['match_train-keywords'].duplicated())].head(30)
# Out:
#     acronym                                               base  \
# 65      BPS  beginning postsecondary students longitudinal ...
# 105   TIMSS            trends in mathematics and science study
# 163   TIMSS  trends in international mathematics and scienc...
# 222     BPS  beginning postsecondary students longitudinal ...
# 238    ECLS               early childhood longitudinal studies
# 285    ARMS       agricultural resource management survey data
# 287    ARMS        agricultural resource and management survey
# 289    ARMS           agricultural resource management surveys
# 291     BPS  beginning postsecondary students longitudinal ...
#
#                                           base_acronym  count_BA  train  \
# 65   beginning postsecondary students longitudinal ...         6   True
# 105      trends in mathematics and science study|TIMSS         2   True
# 163  trends in international mathematics and scienc...         1   True
# 222  beginning postsecondary students longitudinal ...         1   True
# 238          early childhood longitudinal studies|ECLS         1   True
# 285  agricultural resource management survey data|ARMS         1   True
# 287   agricultural resource and management survey|ARMS         1   True
# 289      agricultural resource management surveys|ARMS         4   True
# 291  beginning postsecondary students longitudinal ...         1   True
#
#                                                  match  \
# 65                    beginning postsecondary students
# 105  trends in international mathematics and scienc...
# 163  trends in international mathematics and scienc...
# 222                   beginning postsecondary students
# 238                 early childhood longitudinal study
# 285            agricultural resource management survey
# 287            agricultural resource management survey
# 289            agricultural resource management survey
# 291                   beginning postsecondary students
#
#                                         label-keywords  len_label-keywords  \
# 65                    beginning postsecondary students                   3
# 105                  trends in mathematics and science                   5
# 163  trends in international mathematics and scienc...                   7
# 222                   beginning postsecondary students                   3
# 238                                    early childhood                   2
# 285                   agricultural resource management                   3
# 287               agricultural resource and management                   4
# 289           agricultural resource management surveys                   4
# 291                 beginning postsecondary students 2                   4
#
#                                 match_train-keywords
# 65                  beginning postsecondary students
# 105  trends in international mathematics and science
# 163  trends in international mathematics and science
# 222                 beginning postsecondary students
# 238                                  early childhood
# 285                 agricultural resource management
# 287                 agricultural resource management
# 289                 agricultural resource management
# 291                 beginning postsecondary students

# %%
idx_tmp = df_label_acronym_ver1_all['match_train-keywords']=='no_match'
print(df_label_acronym_ver1_all[idx_tmp].shape)
# high school effectiveness studyのみ誤削除
df_label_acronym_ver1_all[idx_tmp==False]
# Out:
# (303, 9)
#     acronym                                               base  \
# 2       BPS  beginning postsecondary student longitudinal s...
# 9     TIMSS  trends in international mathematics and scienc...
# 14      BPS  beginning postsecondary students longitudinal ...
# 56     ARMS            agricultural resource management survey
# 64    SSOCS                  school survey on crime and safety
# 65      BPS  beginning postsecondary students longitudinal ...
# 93     ECLS                 early childhood longitudinal study
# 105   TIMSS            trends in mathematics and science study
# 163   TIMSS  trends in international mathematics and scienc...
# 194     WOD                               world ocean database
# 208     CCD                                   common core data
# 222     BPS  beginning postsecondary students longitudinal ...
# 228    NTPS              national teacher and principal survey
# 238    ECLS               early childhood longitudinal studies
# 249   SSERF  survey of science and engineering research fac...
# 267    ARMS           agricultural resources management survey
# 285    ARMS       agricultural resource management survey data
# 287    ARMS        agricultural resource and management survey
# 289    ARMS           agricultural resource management surveys
# 291     BPS  beginning postsecondary students longitudinal ...
# 311   NABBS                north american breeding bird survey
# 320    OWID                                  our world in data
#
#                                           base_acronym  count_BA  train  \
# 2    beginning postsecondary student longitudinal s...         2   True
# 9    trends in international mathematics and scienc...       194   True
# 14   beginning postsecondary students longitudinal ...         1   True
# 56        agricultural resource management survey|ARMS       128   True
# 64             school survey on crime and safety|SSOCS         5   True
# 65   beginning postsecondary students longitudinal ...         6   True
# 93             early childhood longitudinal study|ECLS        10   True
# 105      trends in mathematics and science study|TIMSS         2   True
# 163  trends in international mathematics and scienc...         1   True
# 194                           world ocean database|WOD         3   True
# 208                               common core data|CCD         1   True
# 222  beginning postsecondary students longitudinal ...         1   True
# 228         national teacher and principal survey|NTPS         5   True
# 238          early childhood longitudinal studies|ECLS         1   True
# 249  survey of science and engineering research fac...         1   True
# 267      agricultural resources management survey|ARMS         2   True
# 285  agricultural resource management survey data|ARMS         1   True
# 287   agricultural resource and management survey|ARMS         1   True
# 289      agricultural resource management surveys|ARMS         4   True
# 291  beginning postsecondary students longitudinal ...         1   True
# 311          north american breeding bird survey|NABBS         2   True
# 320                             our world in data|OWID         3   True
#
#                                                  match  \
# 2    beginning postsecondary students longitudinal ...
# 9    trends in international mathematics and scienc...
# 14                    beginning postsecondary students
# 56             agricultural resource management survey
# 64                   school survey on crime and safety
# 65                    beginning postsecondary students
# 93                  early childhood longitudinal study
# 105  trends in international mathematics and scienc...
# 163  trends in international mathematics and scienc...
# 194                               world ocean database
# 208                                common core of data
# 222                   beginning postsecondary students
# 228              national teacher and principal survey
# 238                 early childhood longitudinal study
# 249  survey of science and engineering research fac...
# 267            agricultural resource management survey
# 285            agricultural resource management survey
# 287            agricultural resource management survey
# 289            agricultural resource management survey
# 291                   beginning postsecondary students
# 311                north american breeding bird survey
# 320                                  our world in data
#
#                                         label-keywords  len_label-keywords  \
# 2                      beginning postsecondary student                   3
# 9      trends in international mathematics and science                   6
# 14                    beginning postsecondary students                   3
# 56                    agricultural resource management                   3
# 64                          school on crime and safety                   5
# 65                    beginning postsecondary students                   3
# 93                                     early childhood                   2
# 105                  trends in mathematics and science                   5
# 163  trends in international mathematics and scienc...                   7
# 194                               world ocean database                   3
# 208                                        common core                   2
# 222                   beginning postsecondary students                   3
# 228                     national teacher and principal                   4
# 238                                    early childhood                   2
# 249     of science and engineering research facilities                   6
# 267                  agricultural resources management                   3
# 285                   agricultural resource management                   3
# 287               agricultural resource and management                   4
# 289           agricultural resource management surveys                   4
# 291                 beginning postsecondary students 2                   4
# 311                       north american breeding bird                   4
# 320                                       our world in                   3
#
#                                 match_train-keywords
# 2                    beginning postsecondary student
# 9    trends in international mathematics and science
# 14                  beginning postsecondary students
# 56                  agricultural resource management
# 64                        school on crime and safety
# 65                  beginning postsecondary students
# 93                                   early childhood
# 105  trends in international mathematics and science
# 163  trends in international mathematics and science
# 194                             world ocean database
# 208                                      common core
# 222                 beginning postsecondary students
# 228                            teacher and principal
# 238                                  early childhood
# 249      science and engineering research facilities
# 267                agricultural resources management
# 285                 agricultural resource management
# 287                 agricultural resource management
# 289                 agricultural resource management
# 291                 beginning postsecondary students
# 311                     north american breeding bird
# 320                                     our world in

# %%
idx_tmp = df_label_acronym_ver1_all['match']=='no_match'
print(df_label_acronym_ver1_all[idx_tmp].shape)
df_label_acronym_ver1_all[idx_tmp==False]
# Out:
# (270, 9)
#     acronym                                               base  \
# 0      NELS              national education longitudinal study
# 1       NLS                        national longitudinal study
# 2       BPS  beginning postsecondary student longitudinal s...
# 5      NELS      national education longitudinal study of 1988
# 9     TIMSS  trends in international mathematics and scienc...
# 11      WLS                       wisconsin longitudinal study
# 13     NELS  national education longitudinal study 1988 stu...
# 14      BPS  beginning postsecondary students longitudinal ...
# 21     NELS             national education longitudinal survey
# 22     HSES                    high school effectiveness study
# 36     BLSA              baltimore longitudinal study of aging
# 48      CCD                                common core of data
# 56     ARMS            agricultural resource management survey
# 59     ARMS                     and resource management survey
# 64    SSOCS                  school survey on crime and safety
# 65      BPS  beginning postsecondary students longitudinal ...
# 66    NLTS2           national longitudinal transition study 2
# 67    TIMSS  third international mathematics and science study
# 74      SED                        survey of earned doctorates
# 81     TLSA                 taiwan longitudinal study of aging
# 93     ECLS                 early childhood longitudinal study
# 105   TIMSS            trends in mathematics and science study
# 116    NELS            national educational longitudinal study
# 151   TIMSS    the international mathematics and science study
# 154   TIMSS                   trends in math and science study
# 163   TIMSS  trends in international mathematics and scienc...
# 169    GELS           gerontology education longitudinal study
# 170     ELS               education longitudinal study of 2002
# 172    CELS           citizenship education longitudinal study
# 188     SDR                     survey of doctorate recipients
# 194     WOD                               world ocean database
# 208     CCD                                   common core data
# 212    KELS                korean education longitudinal study
# 213     ELS                       education longitudinal study
# 216    NTPS                  national teacher principal survey
# 222     BPS  beginning postsecondary students longitudinal ...
# 228    NTPS              national teacher and principal survey
# 231    NELS               national education lonotudinal study
# 233    NELS            national education longitudinal studies
# 236   ECLSK  early childhood longitudinal study kindergarte...
# 238    ECLS               early childhood longitudinal studies
# 240    HSLS             high school longitudinal study of 2009
# 249   SSERF  survey of science and engineering research fac...
# 253     SDR                      survey of doctoral recipients
# 267    ARMS           agricultural resources management survey
# 283    ARMS             agriculture resource management survey
# 285    ARMS       agricultural resource management survey data
# 286     COA                              census of agriculture
# 287    ARMS        agricultural resource and management survey
# 289    ARMS           agricultural resource management surveys
# 291     BPS  beginning postsecondary students longitudinal ...
# 309     BBS                               breeding bird survey
# 311   NABBS                north american breeding bird survey
# 313     BBS                          breeding bird survey data
# 320    OWID                                  our world in data
#
#                                           base_acronym  count_BA  train  \
# 0           national education longitudinal study|NELS        24   True
# 1                      national longitudinal study|NLS         1   True
# 2    beginning postsecondary student longitudinal s...         2   True
# 5    national education longitudinal study of 1988|...         4   True
# 9    trends in international mathematics and scienc...       194   True
# 11                    wisconsin longitudinal study|WLS         1   True
# 13   national education longitudinal study 1988 stu...         1   True
# 14   beginning postsecondary students longitudinal ...         1   True
# 21         national education longitudinal survey|NELS         3   True
# 22                high school effectiveness study|HSES         1   True
# 36          baltimore longitudinal study of aging|BLSA        58   True
# 48                             common core of data|CCD        18   True
# 56        agricultural resource management survey|ARMS       128   True
# 59                 and resource management survey|ARMS         4   True
# 64             school survey on crime and safety|SSOCS         5   True
# 65   beginning postsecondary students longitudinal ...         6   True
# 66      national longitudinal transition study 2|NLTS2         2   True
# 67   third international mathematics and science st...         6   True
# 74                     survey of earned doctorates|SED        33   True
# 81             taiwan longitudinal study of aging|TLSA         1   True
# 93             early childhood longitudinal study|ECLS        10   True
# 105      trends in mathematics and science study|TIMSS         2   True
# 116       national educational longitudinal study|NELS         6   True
# 151  the international mathematics and science stud...         1   True
# 154             trends in math and science study|TIMSS         1   True
# 163  trends in international mathematics and scienc...         1   True
# 169      gerontology education longitudinal study|GELS         1   True
# 170           education longitudinal study of 2002|ELS         1   True
# 172      citizenship education longitudinal study|CELS         3   True
# 188                 survey of doctorate recipients|SDR        25   True
# 194                           world ocean database|WOD         3   True
# 208                               common core data|CCD         1   True
# 212           korean education longitudinal study|KELS         1   True
# 213                   education longitudinal study|ELS         4   True
# 216             national teacher principal survey|NTPS         2   True
# 222  beginning postsecondary students longitudinal ...         1   True
# 228         national teacher and principal survey|NTPS         5   True
# 231          national education lonotudinal study|NELS         1   True
# 233       national education longitudinal studies|NELS         1   True
# 236  early childhood longitudinal study kindergarte...         1   True
# 238          early childhood longitudinal studies|ECLS         1   True
# 240        high school longitudinal study of 2009|HSLS         1   True
# 249  survey of science and engineering research fac...         1   True
# 253                  survey of doctoral recipients|SDR         3   True
# 267      agricultural resources management survey|ARMS         2   True
# 283        agriculture resource management survey|ARMS         2   True
# 285  agricultural resource management survey data|ARMS         1   True
# 286                          census of agriculture|COA         4   True
# 287   agricultural resource and management survey|ARMS         1   True
# 289      agricultural resource management surveys|ARMS         4   True
# 291  beginning postsecondary students longitudinal ...         1   True
# 309                           breeding bird survey|BBS        72   True
# 311          north american breeding bird survey|NABBS         2   True
# 313                      breeding bird survey data|BBS         1   True
# 320                             our world in data|OWID         3   True
#
#                                                  match  \
# 0                         education longitudinal study
# 1                         education longitudinal study
# 2    beginning postsecondary students longitudinal ...
# 5                         education longitudinal study
# 9    trends in international mathematics and scienc...
# 11                        education longitudinal study
# 13                        education longitudinal study
# 14                    beginning postsecondary students
# 21               national education longitudinal study
# 22                      high school longitudinal study
# 36               baltimore longitudinal study of aging
# 48                                 common core of data
# 56             agricultural resource management survey
# 59             agricultural resource management survey
# 64                   school survey on crime and safety
# 65                    beginning postsecondary students
# 66               national education longitudinal study
# 67   trends in international mathematics and scienc...
# 74                         survey of earned doctorates
# 81               baltimore longitudinal study of aging
# 93                  early childhood longitudinal study
# 105  trends in international mathematics and scienc...
# 116              national education longitudinal study
# 151  trends in international mathematics and scienc...
# 154  trends in international mathematics and scienc...
# 163  trends in international mathematics and scienc...
# 169                       education longitudinal study
# 170                       education longitudinal study
# 172                       education longitudinal study
# 188                     survey of doctorate recipients
# 194                               world ocean database
# 208                                common core of data
# 212                       education longitudinal study
# 213                       education longitudinal study
# 216              national teacher and principal survey
# 222                   beginning postsecondary students
# 228              national teacher and principal survey
# 231              national education longitudinal study
# 233              national education longitudinal study
# 236                 early childhood longitudinal study
# 238                 early childhood longitudinal study
# 240                     high school longitudinal study
# 249  survey of science and engineering research fac...
# 253                     survey of doctorate recipients
# 267            agricultural resource management survey
# 283            agricultural resource management survey
# 285            agricultural resource management survey
# 286                              census of agriculture
# 287            agricultural resource management survey
# 289            agricultural resource management survey
# 291                   beginning postsecondary students
# 309                north american breeding bird survey
# 311                north american breeding bird survey
# 313                north american breeding bird survey
# 320                                  our world in data
#
#                                         label-keywords  len_label-keywords  \
# 0                                   national education                   2
# 1                                             national                   1
# 2                      beginning postsecondary student                   3
# 5                           national education of 1988                   4
# 9      trends in international mathematics and science                   6
# 11                                           wisconsin                   1
# 13                        national education 1988 1994                   4
# 14                    beginning postsecondary students                   3
# 21                                  national education                   2
# 22                           high school effectiveness                   3
# 36                                  baltimore of aging                   3
# 48                                      common core of                   3
# 56                    agricultural resource management                   3
# 59                             and resource management                   3
# 64                          school on crime and safety                   5
# 65                    beginning postsecondary students                   3
# 66                               national transition 2                   3
# 67         third international mathematics and science                   5
# 74                                of earned doctorates                   3
# 81                                     taiwan of aging                   3
# 93                                     early childhood                   2
# 105                  trends in mathematics and science                   5
# 116                               national educational                   2
# 151          the international mathematics and science                   5
# 154                         trends in math and science                   5
# 163  trends in international mathematics and scienc...                   7
# 169                              gerontology education                   2
# 170                                  education of 2002                   3
# 172                              citizenship education                   2
# 188                            of doctorate recipients                   3
# 194                               world ocean database                   3
# 208                                        common core                   2
# 212                                   korean education                   2
# 213                                          education                   1
# 216                         national teacher principal                   3
# 222                   beginning postsecondary students                   3
# 228                     national teacher and principal                   4
# 231                     national education lonotudinal                   3
# 233                                 national education                   2
# 236                 early childhood kindergarten class                   4
# 238                                    early childhood                   2
# 240                                high school of 2009                   4
# 249     of science and engineering research facilities                   6
# 253                             of doctoral recipients                   3
# 267                  agricultural resources management                   3
# 283                    agriculture resource management                   3
# 285                   agricultural resource management                   3
# 286                                     of agriculture                   2
# 287               agricultural resource and management                   4
# 289           agricultural resource management surveys                   4
# 291                 beginning postsecondary students 2                   4
# 309                                      breeding bird                   2
# 311                       north american breeding bird                   4
# 313                                      breeding bird                   2
# 320                                       our world in                   3
#
#                                 match_train-keywords
# 0                                           no_match
# 1                                           no_match
# 2                    beginning postsecondary student
# 5                                           no_match
# 9    trends in international mathematics and science
# 11                                          no_match
# 13                                          no_match
# 14                  beginning postsecondary students
# 21                                          no_match
# 22                                          no_match
# 36                                          no_match
# 48                                          no_match
# 56                  agricultural resource management
# 59                                          no_match
# 64                        school on crime and safety
# 65                  beginning postsecondary students
# 66                                          no_match
# 67                                          no_match
# 74                                          no_match
# 81                                          no_match
# 93                                   early childhood
# 105  trends in international mathematics and science
# 116                                         no_match
# 151                                         no_match
# 154                                         no_match
# 163  trends in international mathematics and science
# 169                                         no_match
# 170                                         no_match
# 172                                         no_match
# 188                                         no_match
# 194                             world ocean database
# 208                                      common core
# 212                                         no_match
# 213                                         no_match
# 216                                         no_match
# 222                 beginning postsecondary students
# 228                            teacher and principal
# 231                                         no_match
# 233                                         no_match
# 236                                         no_match
# 238                                  early childhood
# 240                                         no_match
# 249      science and engineering research facilities
# 253                                         no_match
# 267                agricultural resources management
# 283                                         no_match
# 285                 agricultural resource management
# 286                                         no_match
# 287                 agricultural resource management
# 289                 agricultural resource management
# 291                 beginning postsecondary students
# 309                                         no_match
# 311                     north american breeding bird
# 313                                         no_match
# 320                                     our world in

# %%
df_label_acronym_ver1_all['acronym_clean'] = df_label_acronym_ver1_all['acronym'].apply(clean_text)
df_label_acronym_ver1_all['match_train_acronym'] = df_label_acronym_ver1_all['acronym_clean'].apply(lambda x:
    x in df_label_train_acronym['acronym_clean'].tolist()
                                                                                                   )
df_label_acronym_ver1_all[df_label_acronym_ver1_all['match_train_acronym']]
# Out:
#     acronym                                               base  \
# 0      NELS              national education longitudinal study
# 2       BPS  beginning postsecondary student longitudinal s...
# 3      NELS   national educational longitudinal survey of 1988
# 5      NELS      national education longitudinal study of 1988
# 9     TIMSS  trends in international mathematics and scienc...
# 13     NELS  national education longitudinal study 1988 stu...
# 14      BPS  beginning postsecondary students longitudinal ...
# 15     ECLS  early childhood longitudinal study kindergarte...
# 21     NELS             national education longitudinal survey
# 36     BLSA              baltimore longitudinal study of aging
# 48      CCD                                common core of data
# 56     ARMS            agricultural resource management survey
# 59     ARMS                     and resource management survey
# 64    SSOCS                  school survey on crime and safety
# 65      BPS  beginning postsecondary students longitudinal ...
# 67    TIMSS  third international mathematics and science study
# 72      BPS                                  berea panel study
# 74      SED                        survey of earned doctorates
# 93     ECLS                 early childhood longitudinal study
# 105   TIMSS            trends in mathematics and science study
# 116    NELS            national educational longitudinal study
# 151   TIMSS    the international mathematics and science study
# 154   TIMSS                   trends in math and science study
# 155   TIMSS   the international mathematics and science survey
# 163   TIMSS  trends in international mathematics and scienc...
# 168   TIMSS   the international mathematics and sciences study
# 170     ELS               education longitudinal study of 2002
# 188     SDR                     survey of doctorate recipients
# 194     WOD                               world ocean database
# 208     CCD                                   common core data
# 213     ELS                       education longitudinal study
# 216    NTPS                  national teacher principal survey
# 222     BPS  beginning postsecondary students longitudinal ...
# 228    NTPS              national teacher and principal survey
# 231    NELS               national education lonotudinal study
# 233    NELS            national education longitudinal studies
# 238    ECLS               early childhood longitudinal studies
# 240    HSLS             high school longitudinal study of 2009
# 253     SDR                      survey of doctoral recipients
# 267    ARMS           agricultural resources management survey
# 281    ARMS              a l r e s o u r c e management survey
# 282    ARMS  are derived from partial budget modeling on th...
# 283    ARMS             agriculture resource management survey
# 285    ARMS       agricultural resource management survey data
# 287    ARMS        agricultural resource and management survey
# 289    ARMS           agricultural resource management surveys
# 291     BPS  beginning postsecondary students longitudinal ...
# 309     BBS                               breeding bird survey
# 313     BBS                          breeding bird survey data
#
#                                           base_acronym  count_BA  train  \
# 0           national education longitudinal study|NELS        24   True
# 2    beginning postsecondary student longitudinal s...         2   True
# 3    national educational longitudinal survey of 19...         2   True
# 5    national education longitudinal study of 1988|...         4   True
# 9    trends in international mathematics and scienc...       194   True
# 13   national education longitudinal study 1988 stu...         1   True
# 14   beginning postsecondary students longitudinal ...         1   True
# 15   early childhood longitudinal study kindergarte...         1   True
# 21         national education longitudinal survey|NELS         3   True
# 36          baltimore longitudinal study of aging|BLSA        58   True
# 48                             common core of data|CCD        18   True
# 56        agricultural resource management survey|ARMS       128   True
# 59                 and resource management survey|ARMS         4   True
# 64             school survey on crime and safety|SSOCS         5   True
# 65   beginning postsecondary students longitudinal ...         6   True
# 67   third international mathematics and science st...         6   True
# 72                               berea panel study|BPS         1   True
# 74                     survey of earned doctorates|SED        33   True
# 93             early childhood longitudinal study|ECLS        10   True
# 105      trends in mathematics and science study|TIMSS         2   True
# 116       national educational longitudinal study|NELS         6   True
# 151  the international mathematics and science stud...         1   True
# 154             trends in math and science study|TIMSS         1   True
# 155  the international mathematics and science surv...         1   True
# 163  trends in international mathematics and scienc...         1   True
# 168  the international mathematics and sciences stu...         1   True
# 170           education longitudinal study of 2002|ELS         1   True
# 188                 survey of doctorate recipients|SDR        25   True
# 194                           world ocean database|WOD         3   True
# 208                               common core data|CCD         1   True
# 213                   education longitudinal study|ELS         4   True
# 216             national teacher principal survey|NTPS         2   True
# 222  beginning postsecondary students longitudinal ...         1   True
# 228         national teacher and principal survey|NTPS         5   True
# 231          national education lonotudinal study|NELS         1   True
# 233       national education longitudinal studies|NELS         1   True
# 238          early childhood longitudinal studies|ECLS         1   True
# 240        high school longitudinal study of 2009|HSLS         1   True
# 253                  survey of doctoral recipients|SDR         3   True
# 267      agricultural resources management survey|ARMS         2   True
# 281         a l r e s o u r c e management survey|ARMS         1   True
# 282  are derived from partial budget modeling on th...         1   True
# 283        agriculture resource management survey|ARMS         2   True
# 285  agricultural resource management survey data|ARMS         1   True
# 287   agricultural resource and management survey|ARMS         1   True
# 289      agricultural resource management surveys|ARMS         4   True
# 291  beginning postsecondary students longitudinal ...         1   True
# 309                           breeding bird survey|BBS        72   True
# 313                      breeding bird survey data|BBS         1   True
#
#                                                  match  \
# 0                         education longitudinal study
# 2    beginning postsecondary students longitudinal ...
# 3                                             no_match
# 5                         education longitudinal study
# 9    trends in international mathematics and scienc...
# 13                        education longitudinal study
# 14                    beginning postsecondary students
# 15                                            no_match
# 21               national education longitudinal study
# 36               baltimore longitudinal study of aging
# 48                                 common core of data
# 56             agricultural resource management survey
# 59             agricultural resource management survey
# 64                   school survey on crime and safety
# 65                    beginning postsecondary students
# 67   trends in international mathematics and scienc...
# 72                                            no_match
# 74                         survey of earned doctorates
# 93                  early childhood longitudinal study
# 105  trends in international mathematics and scienc...
# 116              national education longitudinal study
# 151  trends in international mathematics and scienc...
# 154  trends in international mathematics and scienc...
# 155                                           no_match
# 163  trends in international mathematics and scienc...
# 168                                           no_match
# 170                       education longitudinal study
# 188                     survey of doctorate recipients
# 194                               world ocean database
# 208                                common core of data
# 213                       education longitudinal study
# 216              national teacher and principal survey
# 222                   beginning postsecondary students
# 228              national teacher and principal survey
# 231              national education longitudinal study
# 233              national education longitudinal study
# 238                 early childhood longitudinal study
# 240                     high school longitudinal study
# 253                     survey of doctorate recipients
# 267            agricultural resource management survey
# 281                                           no_match
# 282                                           no_match
# 283            agricultural resource management survey
# 285            agricultural resource management survey
# 287            agricultural resource management survey
# 289            agricultural resource management survey
# 291                   beginning postsecondary students
# 309                north american breeding bird survey
# 313                north american breeding bird survey
#
#                                         label-keywords  len_label-keywords  \
# 0                                   national education                   2
# 2                      beginning postsecondary student                   3
# 3                         national educational of 1988                   4
# 5                           national education of 1988                   4
# 9      trends in international mathematics and science                   6
# 13                        national education 1988 1994                   4
# 14                    beginning postsecondary students                   3
# 15       early childhood kindergarten class of 1998 99                   7
# 21                                  national education                   2
# 36                                  baltimore of aging                   3
# 48                                      common core of                   3
# 56                    agricultural resource management                   3
# 59                             and resource management                   3
# 64                          school on crime and safety                   5
# 65                    beginning postsecondary students                   3
# 67         third international mathematics and science                   5
# 72                                               berea                   1
# 74                                of earned doctorates                   3
# 93                                     early childhood                   2
# 105                  trends in mathematics and science                   5
# 116                               national educational                   2
# 151          the international mathematics and science                   5
# 154                         trends in math and science                   5
# 155          the international mathematics and science                   5
# 163  trends in international mathematics and scienc...                   7
# 168         the international mathematics and sciences                   5
# 170                                  education of 2002                   3
# 188                            of doctorate recipients                   3
# 194                               world ocean database                   3
# 208                                        common core                   2
# 213                                          education                   1
# 216                         national teacher principal                   3
# 222                   beginning postsecondary students                   3
# 228                     national teacher and principal                   4
# 231                     national education lonotudinal                   3
# 233                                 national education                   2
# 238                                    early childhood                   2
# 240                                high school of 2009                   4
# 253                             of doctoral recipients                   3
# 267                  agricultural resources management                   3
# 281                     a l r e s o u r c e management                  11
# 282  are derived from partial budget modeling on th...                  11
# 283                    agriculture resource management                   3
# 285                   agricultural resource management                   3
# 287               agricultural resource and management                   4
# 289           agricultural resource management surveys                   4
# 291                 beginning postsecondary students 2                   4
# 309                                      breeding bird                   2
# 313                                      breeding bird                   2
#
#                                 match_train-keywords acronym_clean  \
# 0                                           no_match          nels
# 2                    beginning postsecondary student           bps
# 3                                           no_match          nels
# 5                                           no_match          nels
# 9    trends in international mathematics and science         timss
# 13                                          no_match          nels
# 14                  beginning postsecondary students           bps
# 15                                          no_match          ecls
# 21                                          no_match          nels
# 36                                          no_match          blsa
# 48                                          no_match           ccd
# 56                  agricultural resource management          arms
# 59                                          no_match          arms
# 64                        school on crime and safety         ssocs
# 65                  beginning postsecondary students           bps
# 67                                          no_match         timss
# 72                                          no_match           bps
# 74                                          no_match           sed
# 93                                   early childhood          ecls
# 105  trends in international mathematics and science         timss
# 116                                         no_match          nels
# 151                                         no_match         timss
# 154                                         no_match         timss
# 155                                         no_match         timss
# 163  trends in international mathematics and science         timss
# 168                                         no_match         timss
# 170                                         no_match           els
# 188                                         no_match           sdr
# 194                             world ocean database           wod
# 208                                      common core           ccd
# 213                                         no_match           els
# 216                                         no_match          ntps
# 222                 beginning postsecondary students           bps
# 228                            teacher and principal          ntps
# 231                                         no_match          nels
# 233                                         no_match          nels
# 238                                  early childhood          ecls
# 240                                         no_match          hsls
# 253                                         no_match           sdr
# 267                agricultural resources management          arms
# 281                                         no_match          arms
# 282                                         no_match          arms
# 283                                         no_match          arms
# 285                 agricultural resource management          arms
# 287                 agricultural resource management          arms
# 289                 agricultural resource management          arms
# 291                 beginning postsecondary students           bps
# 309                                         no_match           bbs
# 313                                         no_match           bbs
#
#      match_train_acronym
# 0                   True
# 2                   True
# 3                   True
# 5                   True
# 9                   True
# 13                  True
# 14                  True
# 15                  True
# 21                  True
# 36                  True
# 48                  True
# 56                  True
# 59                  True
# 64                  True
# 65                  True
# 67                  True
# 72                  True
# 74                  True
# 93                  True
# 105                 True
# 116                 True
# 151                 True
# 154                 True
# 155                 True
# 163                 True
# 168                 True
# 170                 True
# 188                 True
# 194                 True
# 208                 True
# 213                 True
# 216                 True
# 222                 True
# 228                 True
# 231                 True
# 233                 True
# 238                 True
# 240                 True
# 253                 True
# 267                 True
# 281                 True
# 282                 True
# 283                 True
# 285                 True
# 287                 True
# 289                 True
# 291                 True
# 309                 True
# 313                 True

# %%
# NLTS2, ECLSKが問題か
print(df_label_acronym_ver1_all.shape)
df_label_acronym_ver1_all.to_csv(params['OUTPUT_DIR']+"/df_label_acronym_ver1_all_210619_02.csv", index=None)
# Out:
# (325, 11)
